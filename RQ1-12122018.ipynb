# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('data/wiki-topcats-reduced.txt', sep="	", header=None)
data.columns = ["from", "to"]
data.head()
# Out:
#    from       to
# 0    52   401135
# 1    52  1069112
# 2    52  1163551
# 3    62    12162
# 4    62   167659

# %%
data.isnull().sum()
# Out:
# from    0
# to      0
# dtype: int64

# %%
len(data)
# Out:
# 2645247

# %%
len(data.drop_duplicates())
# Out:
# 2645247

# %%
G=nx.Graph()

# %%
for i,row in data.iterrows():
    H.add_edge(row['from'], row['to'])
    if (i == 100):
        break
partition = community.best_partition(H)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-d857715f2ad0> in <module>()
#       3     if (i == 100):
#       4         break
# ----> 5 partition = community.best_partition(H)
#
# AttributeError: module 'community' has no attribute 'best_partition'

# %%
pos = nx.spring_layout(H)  # compute graph layout
plt.figure(figsize=(10, 10))
plt.axis('off')
nx.draw_networkx_nodes(H, pos, node_size=600, cmap=plt.cm.RdYlBu, node_color=list(partition.values()))
nx.draw_networkx_edges(H, pos, alpha=0.3)
plt.show(H)

# %%
u = set(list(data['from']) + list(data['to']))

# %%
for i in u:
    G.add_node(i)

# %%
edges = []
nodes = []
for i, row in enumerate(data.itertuples()):
    edges += [(row[1],row[2])]
    if(row[1] not in nodes):
        nodes += [row[1]]
    if(row[2] not in nodes):
        nodes += [row[2]]
    if(i == 1000):
        break
#     G.add_edge(row['from'], row['to'])
edges
# Out:
# [(52, 401135),
#  (52, 1069112),
#  (52, 1163551),
#  (62, 12162),
#  (62, 167659),
#  (62, 279122),
#  (62, 1089199),
#  (62, 1354553),
#  (62, 1400636),
#  (62, 1403619),
#  (62, 1537692),
#  (62, 1544420),
#  (64, 64873),
#  (66, 279122),
#  (66, 1163290),
#  (74, 279122),
#  (95, 1179478),
#  (95, 1185516),
#  (95, 1185519),
#  (95, 1230865),
#  (103, 107),
#  (104, 107),
#  (104, 1174251),
#  (104, 1174302),
#  (105, 1174967),
#  (107, 104),
#  (107, 142167),
#  (107, 657930),
#  (107, 1013995),
#  (107, 1061780),
#  (107, 1174302),
#  (107, 1179210),
#  (107, 1181401),
#  (108, 104),
#  (108, 107),
#  (108, 1059989),
#  (108, 1062426),
#  (108, 1161925),
#  (108, 1169534),
#  (112, 107),
#  (113, 279122),
#  (113, 1185127),
#  (122, 1174967),
#  (126, 279122),
#  (133, 279122),
#  (133, 825464),
#  (134, 541222),
#  (134, 1060414),
#  (134, 1061485),
#  (134, 1062226),
#  (134, 1163610),
#  (134, 1163783),
#  (134, 1265505),
#  (137, 136),
#  (137, 1163286),
#  (137, 1163712),
# ...

# %%
G.add_nodes_from(nodes)
G.add_edges_from(edges)

# %%
# nx.draw()
pos = nx.spring_layout(G)  # compute graph layout
plt.figure(figsize=(10, 10))
plt.axis('off')
nx.draw_networkx_nodes(G, pos, node_size=20, cmap=plt.cm.RdYlBu, node_color='blue', alpha=0.3)
nx.draw_networkx_edges(G, pos, alpha=0.5)
plt.show(G)

# %%
revedges = set()
edges = set()
for i, row in enumerate(data.itertuples()):
    edges.add((row[1],row[2]))
    revedges.add((row[2],row[1]))

# %%
len(revedges.intersection(edges))
# Out:
# 942369

# %%
revedges.intersection(edges)
# Out:
# {(1321584, 1321648),
#  (386992, 386890),
#  (1216675, 1216662),
#  (944002, 1236319),
#  (1720032, 1740967),
#  (1022388, 1022141),
#  (1320471, 1320474),
#  (426722, 1059023),
#  (1044081, 1044077),
#  (1044826, 1162073),
#  (1227311, 1169179),
#  (1062355, 1060668),
#  (384888, 385021),
#  (1058455, 1664234),
#  (1057651, 1266003),
#  (1061066, 823961),
#  (1367477, 1058472),
#  (633781, 594088),
#  (1163472, 1063060),
#  (1549625, 1549525),
#  (796228, 1180106),
#  (1063389, 1063452),
#  (425389, 424791),
#  (1269362, 1267373),
#  (1163179, 1163177),
#  (1266156, 1508396),
#  (492564, 491710),
#  (1391656, 1391541),
#  (1745408, 1745453),
#  (1178530, 1194145),
#  (1049087, 1066907),
#  (947370, 947662),
#  (494258, 494131),
#  (81546, 82177),
#  (1247912, 1267324),
#  (1597228, 1595932),
#  (761203, 761204),
#  (537242, 535916),
#  (762456, 762410),
#  (1599676, 1177682),
#  (589390, 589628),
#  (1033897, 1056751),
#  (569629, 107796),
#  (1503936, 1504205),
# ...

# %% [markdown]
# This is the number of nodes if we consider the two direction arrows as one edge

# %%
len(edges - revedges.intersection(edges))
# Out:
# 1702878
